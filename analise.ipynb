# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df = pd.read_csv('data.csv', parse_dates=['date'], date_parser=d_parser)
# Out:
# <ipython-input-3-1ceb3ed007a1>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')

# %%
df.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.loc[0,'date'].day_name()
# Out:
# 'Monday'

# %%
df.shape
# Out:
# (89466, 59)

# %%
df.loc[0,'date']
# Out:
# Timestamp('2020-02-24 00:00:00')

# %%
df['date']
# Out:
# 0       2020-02-24
# 1       2020-02-25
# 2       2020-02-26
# 3       2020-02-27
# 4       2020-02-28
#            ...
# 89461   2021-05-11
# 89462   2021-05-12
# 89463   2021-05-13
# 89464   2021-05-14
# 89465   2021-05-15
# Name: date, Length: 89466, dtype: datetime64[ns]

# %%
df['date'].dt.month_name()
# Out:
# 0        February
# 1        February
# 2        February
# 3        February
# 4        February
#            ...
# 89461         May
# 89462         May
# 89463         May
# 89464         May
# 89465         May
# Name: date, Length: 89466, dtype: object

# %%
df['month_name']=df['date'].dt.month_name()

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
df['location']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 89461       Zimbabwe
# 89462       Zimbabwe
# 89463       Zimbabwe
# 89464       Zimbabwe
# 89465       Zimbabwe
# Name: location, Length: 89466, dtype: object

# %%
ro=df[df.location =='Romania']

# %%
isr=df[df.location=='Israel']

# %%
isr
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 39797      ISR      Asia   Israel 2020-02-20          NaN        NaN
# 39798      ISR      Asia   Israel 2020-02-21          1.0        1.0
# 39799      ISR      Asia   Israel 2020-02-22          1.0        0.0
# 39800      ISR      Asia   Israel 2020-02-23          1.0        0.0
# 39801      ISR      Asia   Israel 2020-02-24          1.0        0.0
# ...        ...       ...      ...        ...          ...        ...
# 40243      ISR      Asia   Israel 2021-05-11     839000.0       43.0
# 40244      ISR      Asia   Israel 2021-05-12     839030.0       30.0
# 40245      ISR      Asia   Israel 2021-05-13     839059.0       29.0
# 40246      ISR      Asia   Israel 2021-05-14     839079.0       20.0
# 40247      ISR      Asia   Israel 2021-05-15     839118.0       39.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
ro
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 65960      ROU    Europe  Romania 2020-02-26          1.0        1.0
# 65961      ROU    Europe  Romania 2020-02-27          1.0        0.0
# 65962      ROU    Europe  Romania 2020-02-28          3.0        2.0
# 65963      ROU    Europe  Romania 2020-02-29          3.0        0.0
# 65964      ROU    Europe  Romania 2020-03-01          3.0        0.0
# ...        ...       ...      ...        ...          ...        ...
# 66400      ROU    Europe  Romania 2021-05-11    1067887.0     1156.0
# 66401      ROU    Europe  Romania 2021-05-12    1068817.0      930.0
# 66402      ROU    Europe  Romania 2021-05-13    1069770.0      953.0
# 66403      ROU    Europe  Romania 2021-05-14    1070605.0      835.0
# 66404      ROU    Europe  Romania 2021-05-15    1071334.0      729.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
ro_cases=ro['total_cases']

# %%
ro_cases
# Out:
# 65960          1.0
# 65961          1.0
# 65962          3.0
# 65963          3.0
# 65964          3.0
#            ...
# 66400    1067887.0
# 66401    1068817.0
# 66402    1069770.0
# 66403    1070605.0
# 66404    1071334.0
# Name: total_cases, Length: 445, dtype: float64

# %%
df['date']
# Out:
# 0       2020-02-24
# 1       2020-02-25
# 2       2020-02-26
# 3       2020-02-27
# 4       2020-02-28
#            ...
# 89461   2021-05-11
# 89462   2021-05-12
# 89463   2021-05-13
# 89464   2021-05-14
# 89465   2021-05-15
# Name: date, Length: 89466, dtype: datetime64[ns]

# %%
# %matplotlib inline

# %%
from datetime import datetime
from matplotlib.dates import date2num

# %%
import seaborn as sns

# %%
# %matplotlib qt

# %%
plt.plot(isr.date,isr.new_cases_smoothed)


#plt.axvspan(date2num(datetime(2021,3,15)), date2num(datetime(2021,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,3,15)), date2num(datetime(2020,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,11,5)), date2num(datetime(2020,12,5)), label="Lockdown",color="lightblue", alpha=0.3)
plt.legend(['Infectari noi'])
plt.title('Date zilnice')
plt.xlabel('Lună')
plt.ylabel('Număr')
sns.set_theme()


plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(10.7,6.27)})

# %%
plt.plot(ro.date,ro.total_cases/10**6)
plt.plot(ro.date,ro.people_fully_vaccinated/10**6)


#plt.axvspan(date2num(datetime(2021,3,15)), date2num(datetime(2021,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,3,15)), date2num(datetime(2020,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,11,5)), date2num(datetime(2020,12,5)), label="Lockdown",color="lightblue", alpha=0.3)
plt.legend(['Infectari noi','Numarul oamenilor imunizati'])
plt.title('Date zilnice')
plt.xlabel('Lună')
plt.ylabel('Număr de oameni (milioane)')
sns.set_theme()


plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(10.7,6.27)})

# %%
v1 =ro[
    (ro['date'] >= datetime(2020,3,15)) & 
    (ro['date'] <= datetime(2020,5,15))
]

# %%
plt.plot(v1.date,v1.new_cases_smoothed)

plt.axvspan(date2num(datetime(2020,3,24)), date2num(datetime(2020,4,7)), label="2w",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,3,15)), date2num(datetime(2020,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,11,5)), date2num(datetime(2020,12,5)), label="Lockdown",color="lightblue", alpha=0.3)
plt.legend(['Infectari noi'])
plt.title('Valul 1')
plt.xlabel('Data')
plt.ylabel('Număr')
sns.set_theme()
#pe 24 martie au fost introduse cele mai dure masuri
#valul1

plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(10.7,6.27)})

# %%
v2 =ro[
    (ro['date'] >= datetime(2020,10,1)) & 
    (ro['date'] <= datetime(2021,1,1))
]

# %%
plt.plot(v2.date,v2.new_cases_smoothed)

plt.axvspan(date2num(datetime(2020,11,5)), date2num(datetime(2020,11,19)), label="2w",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,3,15)), date2num(datetime(2020,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,11,5)), date2num(datetime(2020,12,5)), label="Lockdown",color="lightblue", alpha=0.3)
plt.legend(['Infectari noi'])
plt.title('Valul 2')
plt.xlabel('Data')
plt.ylabel('Număr')
sns.set_theme()
#pe 5 noiembrie au fost introduse cele mai dure masuri
#valul2

plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(10.7,6.27)})

# %%
v3 =ro[
    (ro['date'] >= datetime(2021,2,15)) & 
    (ro['date'] <= datetime(2021,5,1))
]

# %%
 plt.plot(v3.date,v3.new_cases_smoothed)

plt.axvspan(date2num(datetime(2021,3,15)), date2num(datetime(2021,3,29)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,3,15)), date2num(datetime(2020,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,11,5)), date2num(datetime(2020,12,5)), label="Lockdown",color="lightblue", alpha=0.3)
plt.legend(['Infectari noi'])
plt.title('Valul 3')
plt.xlabel('Lună')
plt.ylabel('Număr')
sns.set_theme()
#pe 15 martie au fost introduse restrictii

plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(10.7,6.27)})

# %%
import numpy

# %%
v1
# Out:
#       iso_code continent location       date  total_cases  new_cases  \
# 65978      ROU    Europe  Romania 2020-03-15        131.0        8.0
# 65979      ROU    Europe  Romania 2020-03-16        158.0       27.0
# 65980      ROU    Europe  Romania 2020-03-17        184.0       26.0
# 65981      ROU    Europe  Romania 2020-03-18        260.0       76.0
# 65982      ROU    Europe  Romania 2020-03-19        277.0       17.0
# ...        ...       ...      ...        ...          ...        ...
# 66035      ROU    Europe  Romania 2020-05-11      15588.0      226.0
# 66036      ROU    Europe  Romania 2020-05-12      15778.0      190.0
# 66037      ROU    Europe  Romania 2020-05-13      16002.0      224.0
# 66038      ROU    Europe  Romania 2020-05-14      16247.0      245.0
# 66039      ROU    Europe  Romania 2020-05-15      16437.0      190.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
numpy.cov(df.total_cases,df.total_deaths)
# Out:
# array([[nan, nan],
#        [nan, nan]])

# %%
numpy.cov(ro.total_cases,ro.total_cases)
# Out:
# array([[1.40174293e+11, 1.40174293e+11],
#        [1.40174293e+11, 1.40174293e+11]])

# %%
numpy.cov(ro.total_cases,ro.total_deaths)
# Out:
# array([[1.40174293e+11,            nan],
#        [           nan,            nan]])

# %%
numpy.cov(ro.total_cases,ro.total_deaths)
# Out:
# array([[1.40174293e+11,            nan],
#        [           nan,            nan]])

# %%
numpy.cov(ro.total_cases,ro.total_deaths,bias=True)[0][1]
# Out:
# nan

# %%
numpy.stdev(ro.total_cases/ro.total_deaths)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-75f005a1c922> in <module>
# ----> 1 numpy.stdev(ro.total_cases/ro.total_deaths)
#
# ~\Anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     212                 return Tester
#     213             else:
# --> 214                 raise AttributeError("module {!r} has no attribute "
#     215                                      "{!r}".format(__name__, attr))
#     216
#
# AttributeError: module 'numpy' has no attribute 'stdev'

# %%
ro.cov()

# %%
ro.corr(method='pearson')

# %%
world=df.corr(method='pearson')

# %%
world

# %%
out=ro.corr(method='pearson')

# %%
out

# %%
out.to_csv(r'C:\Users\stefan.bobeica2501\Desktop\DATA_m3')

# %%
import csv

# %%
out.to_excel('corelatii.xlsx')

# %%
out

# %%
cov=ro.cov()

# %%
cov

# %%
cov.to_excel('covariatii.xlsx')

# %%
ro.var

# %% [raw]
# ro.var()

# %%
x=ro.var()

# %%
ro['male_smokers']

# %%
ro.describe()

# %%
ro.isnull().sum()

# %%
import seaborn as sns

# %%
eu=df[df.continent=='Europe']

# %%
td=eu[eu.date== datetime(2021,5,15)]

# %%
plt.plot(ro.date,ro.people_fully_vaccinated/10**6)
plt.plot(ro.date,ro.total_cases/10**6)

#plt.axvspan(date2num(datetime(2021,3,15)), date2num(datetime(2021,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,3,15)), date2num(datetime(2020,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,11,5)), date2num(datetime(2020,12,5)), label="Lockdown",color="lightblue", alpha=0.3)
plt.legend(['Oameni Imunizati','Cazuri totale'])
plt.title('Imunizati vs Infectati')
plt.xlabel('Lună')
plt.ylabel('Număr(milioabe)')
sns.set_theme()


plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(10.7,6.27)})

# %%
tara=df[df.location=='India']


plt.plot(tara.date,tara.new_cases_smoothed)


#plt.axvspan(date2num(datetime(2021,3,15)), date2num(datetime(2021,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,3,15)), date2num(datetime(2020,5,15)), label="Lockdown",color="lightblue", alpha=0.3)
#plt.axvspan(date2num(datetime(2020,11,5)), date2num(datetime(2020,12,5)), label="Lockdown",color="lightblue", alpha=0.3)
plt.legend(['Cazuri zilnice'])
plt.title('Cazuri zilnice in timp')
plt.xlabel('Lună')
plt.ylabel('Număr')
sns.set_theme()


plt.tight_layout()
plt.show()
sns.set(rc={'figure.figsize':(10.7,6.27)})
